# %% [markdown]
# # test report: comparison with reference dem

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from cryoswath import l2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from cryoswath import l2
#
# File ~/Documents/PhD/projects/2023__cryoswath/cryoswath/__init__.py:15
#       3 __all__ = [
#       4     "__version__",
#       5     "misc",
#    (...)     11     "test_plots",  # subpackage
#      12 ]
#      14 from importlib.metadata import version as _version
# ---> 15 from cryoswath import gis, misc, l1b, l2, l3, l4, test_plots
#      18 # copied from xarray
#      19 try:
#
# File ~/Documents/PhD/projects/2023__cryoswath/cryoswath/gis.py:15
#       1 """Geospatial helper functions used throughout CryoSwath workflows."""
#       3 __all__ = [
#       4     "find_planar_crs",
#       5     "buffer_4326_shp",
#    (...)     12     "get_lon_origin",
#      13 ]
# ---> 15 import geopandas as gpd
#      16 import numpy as np
#      17 import os
#
# ...

# %%
from cryoswath import l1b

# %%
l1b_data = l1b.append_best_fit_phase_index(l1b.from_id("20140517T225409"))
# Out:
# /home/jan/Documents/PhD/projects/2023__cryoswath/.pixi/envs/test/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:592: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /home/jan/Documents/PhD/projects/2023__cryoswath/cryoswath/misc.py:614: UserWarning: Dropping 80 glaciers < 1 km² from RGI o1 region.
#   warnings.warn(

# %%
import xarray as xr
xr.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.11.14 | packaged by conda-forge | (main, Jan 26 2026, 23:48:32) [GCC 14.3.0]
# python-bits: 64
# OS: Linux
# OS-release: 5.15.0-170-generic
# machine: x86_64
# processor: x86_64
# byteorder: little
# LC_ALL: None
# LANG: en_US.UTF-8
# LOCALE: ('en_US', 'UTF-8')
# libhdf5: 1.14.6
# libnetcdf: None
#
# xarray: 2025.11.0
# pandas: 3.0.0
# numpy: 2.4.2
# scipy: 1.17.0
# netCDF4: None
# pydap: None
# h5netcdf: 1.8.1
# h5py: 3.15.1
# zarr: 3.1.5
# cftime: None
# nc_time_axis: None
# iris: None
# bottleneck: 1.6.0
# dask: 2026.1.2
# distributed: 2026.1.2
# matplotlib: 3.10.8
# cartopy: None
# seaborn: None
# numbagg: None
# fsspec: 2026.2.0
# cupy: None
# pint: None
# sparse: None
# flox: None
# numpy_groupies: None
# setuptools: 82.0.0
# pip: 26.0.1
# conda: None
# pytest: 9.0.2
# mypy: None
# IPython: 9.10.0
# sphinx: None
# ...

# %%
l1b.to_l2(l1b_data)
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:            (time_20_ku: 382, ns_20_ku: 1024)
# Coordinates:
#   * ns_20_ku           (ns_20_ku) int64 8kB 0 1 2 3 4 ... 1020 1021 1022 1023
#   * time               (time_20_ku) datetime64[ns] 3kB 2014-05-17T22:54:43.78...
#     lat_20_ku          (time_20_ku) float64 3kB 75.32 75.32 ... 76.35 76.36
#     lon_20_ku          (time_20_ku) float64 3kB 62.98 62.98 ... 62.29 62.29
#     phase_wrap_factor  (time_20_ku, ns_20_ku) int64 3MB 0 0 0 0 ... -1 -1 -1 -1
#     band               int64 8B 1
#     spatial_ref        int64 8B 0
# Dimensions without coordinates: time_20_ku
# Data variables:
#     x                  (time_20_ku, ns_20_ku) float64 3MB nan nan ... nan nan
#     y                  (time_20_ku, ns_20_ku) float64 3MB nan nan ... nan nan
#     height             (time_20_ku, ns_20_ku) float64 3MB nan nan ... nan nan
#     h_ref              (time_20_ku, ns_20_ku) float32 2MB nan nan ... nan nan
# ...

# %%
l2_swath, l2_poca = l2.from_id("20140517T225409")
# Out:
# [note] You can speed up processing substantially by previously downloading the L1b data.
# start processing 2014-05-01 00:00:00
# getting 2014-05-17 22:54:09
# /home/jan/Documents/PhD/projects/2023__cryoswath/.pixi/envs/test/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:592: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# /home/jan/Documents/PhD/projects/2023__cryoswath/cryoswath/misc.py:614: UserWarning: Dropping 80 glaciers < 1 km² from RGI o1 region.
#   warnings.warn(
# KeysView(Data variables:
#     agc_ch1_20_ku                           (time_20_ku) float64 3kB ...
#     agc_ch2_20_ku                           (time_20_ku) float64 3kB ...
#     alt_20_ku                               (time_20_ku) float64 3kB ...
# ...

# %%
l2_swath
# Out:
# Empty GeoDataFrame
# Columns: [dummy, geometry]
# Index: []

# %%
l2_swath["h_diff"].plot.hist(density=True, alpha=.7, label=f"swath Σ{l2_swath.shape[0]}")
l2_poca["h_diff"].plot.hist(density=True, alpha=.7, label=f"poca Σ{l2_poca.shape[0]}")
plt.legend()
plt.xlabel("L2 - DEM, meter");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/PhD/projects/2023__cryoswath/.pixi/envs/test/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'h_diff'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ...

# %%
l2_swath["h_diff"].plot.hist(bins=np.arange(-50.5, 51), density=True, alpha=.7, label="swath")
l2_poca["h_diff"].plot.hist(bins=np.arange(-50.5, 51), density=True, alpha=.7, label="poca")
plt.legend()
plt.xlabel("L2 - DEM, meter");

# %% [markdown]
# ## swath stats

# %%
l2_swath.h_diff.describe()

# %% [markdown]
# ## poca stats

# %%
l2_poca.h_diff.describe()
